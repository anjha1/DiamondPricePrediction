# %% [markdown]
# ## 🟩 **Diamond Price Prediction – Problem Statement**
#
# ### 🎯 **Objective**:
#
# To build a regression model that can **predict the price** of a diamond based on various features (independent variables).
#
# ---
#
# ### 📊 **Dataset Overview**:
#
# The dataset contains multiple features (columns) used to predict the target variable `price`.
#
# ---
#
# ### 🧾 **Features (Independent Variables)**:
#
# There are **10 independent variables**:
#
# 1. **id**: Unique identifier for each diamond
# 2. **carat**: Carat weight of the diamond
# 3. **cut**: Quality of the diamond cut
# 4. **color**: Color grade of the diamond
# 5. **clarity**: Purity and rarity, based on inclusions and blemishes
# 6. **depth**: Height of the diamond (mm), from the culet to the table
# 7. **table**: Width of the diamond’s top facet when viewed face-up
# 8. **x**: Length dimension (in mm)
# 9. **y**: Width dimension (in mm)
# 10. **z**: Depth dimension (in mm)
#
# ---
#
# ### 🎯 **Target Variable**:
#
# * **price**: Price of the given diamond (numerical, continuous)
#
# ---
#
# ### 🔗 **Dataset Source**:
#
# Available on Kaggle:
# [https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv](https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv)
#
# ---

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn scipy xgboost  plotly

# %%
import pandas as pd

# %%
## Data Ingestions Step
df=pd.read_csv('data/gemstone.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
## No missing value present in the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
##Lets Drop the id column
df=df.drop(labels=['id'],axis=1)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## Check for the duplicate record
df.duplicated().sum()
# Out:
# 0

# %%
# segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:", numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Categorical Columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns]
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
df[numerical_columns]
# Out:
#         carat  depth  table     x     y     z  price
# 0        1.52   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...    ...    ...   ...   ...   ...    ...
# 193568   0.31   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 7 columns]

# %%
##Statistics
df[numerical_columns].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%  \
# carat  193573.0     0.790688     0.462688    0.2    0.40     0.70     1.03
# depth  193573.0    61.820574     1.081704   52.1   61.30    61.90    62.40
# table  193573.0    57.227675     1.918844   49.0   56.00    57.00    58.00
# x      193573.0     5.715312     1.109422    0.0    4.70     5.70     6.51
# y      193573.0     5.720094     1.102333    0.0    4.71     5.72     6.51
# z      193573.0     3.534246     0.688922    0.0    2.90     3.53     4.03
# price  193573.0  3969.155414  4034.374138  326.0  951.00  2401.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00

# %%
##Data Types
df[numerical_columns].dtypes
# Out:
# carat    float64
# depth    float64
# table    float64
# x        float64
# y        float64
# z        float64
# price      int64
# dtype: object

# %%
## Correlation Matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
##  Distribution Plots (Histogram or KDE)
import seaborn as sns

for col in numerical_columns:
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
## Boxplots (Outlier Detection)
for col in numerical_columns:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df[numerical_columns].skew()
# Out:
# carat    0.995135
# depth   -0.276382
# table    0.619062
# x        0.361050
# y        0.356758
# z        0.685671
# price    1.605581
# dtype: float64

# %%
df[numerical_columns].kurt()
# Out:
# carat     0.537398
# depth     2.477041
# table     0.810180
# x        -0.801006
# y        -0.810668
# z        12.818313
# price     2.106914
# dtype: float64

# %%
## Z-Score or IQR for Outlier Removal
from scipy.stats import zscore

z_scores = zscore(df[numerical_columns])
abs_z_scores = abs(z_scores)

# Keep rows where all z-scores < 3
df_no_outliers_z = df[(abs_z_scores < 3).all(axis=1)]
print("Original shape:", df.shape)
print("Shape after Z-score outlier removal:", df_no_outliers_z.shape)
# Out:
# Original shape: (193573, 10)
# Shape after Z-score outlier removal: (185074, 10)

# %%
df[numerical_columns].std().sort_values(ascending=False)
# Out:
# price    4034.374138
# table       1.918844
# x           1.109422
# y           1.102333
# depth       1.081704
# z           0.688922
# carat       0.462688
# dtype: float64

# %%
sns.heatmap(df[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
## currently we will not use this
## df.drop(labels=['x','y','z'],axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %% [markdown]
# https://www.americangemsociety.org/ags-diamond-grading-system/

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {"D":1, "E":2, "F":3, "G":4, "H":5, "I":6, "J":7}

# %%
df['cut']=df['cut'].map(cut_map)
df['clarity'] = df['clarity'].map(clarity_map)
df['color'] = df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
